# %% [markdown]
# <p style="text-align: center">
# <img src="../../assets/images/dtlogo.png" alt="Duckietown" width="50%">
# </p>

# %% [markdown]
# # Object Detection
#
# Machine-learned object detection models can be extremely useful. They are faster and often more reliable than traditional computer vision models. Additionally, we can use pretrained model weights to cut down immensely on training time.
#
# Here's an example of what an object detector might output:

# %% [markdown]
# <iframe width="800" height="500"
# src="https://www.youtube.com/embed/3jD02dxL6gg"
# frameborder="0"
# allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture"
# allowfullscreen
# style="margin: auto; display: block"></iframe>

# %% [markdown]
# In this exercise, you will create your own Duckietown object detection dataset. You will learn about the general structure such a dataset should follow. You will train the object detection model on that dataset ([in a subsequent notebook](../03-Training/training.ipynb). Finally, you will integrate the model into a ROS node and test the integration ([in the last notebook](../04-Integration/integration.ipynb), so that your Duckiebot knows how to recognize duckie pedestrians (and thus avoid them). You can test your object detector in simulation and on your real Duckiebot.
#
# ### Steps:
#
# 1. Setup
# 2. Investigation
# 3. Data collection
# 4. Training
# 5. Integration

# %% [markdown]
# ## 1. Setup
#
# First, we need some global variables. These allow you to change the directory where we store the data you will need. You can also change the image size to reflect what your final model uses, but you can worry about that later.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
DATASET_DIR="/code/object-detection/assets/duckietown_object_detection_dataset"
IMAGE_SIZE = 416
# this is the percentage of real data that will go into the training set (as opposed to the testing set)
REAL_TRAIN_TEST_SPLIT_PERCENTAGE = 0.8

# %% [markdown]
# While you will build your own dataset with simulated images in part 2, it would be unreasonable to ask you to build your own dataset of real images. Run the cell below to download a dataset of pre-labelled real images.

# %%
from utils.misc import runp

# download dataset
if not os.path.exists(DATASET_DIR):
    runp(f"rm -rf {DATASET_DIR}/*")
    runp(f"mkdir -p {DATASET_DIR}/images")
    runp(f"mkdir -p {DATASET_DIR}/labels")
    runp(f"mkdir -p {DATASET_DIR}/train/images")
    runp(f"mkdir -p {DATASET_DIR}/train/labels")
    runp(f"mkdir -p {DATASET_DIR}/val/images")
    runp(f"mkdir -p {DATASET_DIR}/val/labels")
else:
    print("Folder structure already exists!")

# download dataset
if not os.path.exists(f"{DATASET_DIR}/frames"):
    # !wget -O /tmp/dataset.zip https://duckietown-public-storage.s3.amazonaws.com/assets/mooc/2022/duckietown_object_detection_dataset.zip
    runp(f"unzip -q /tmp/dataset.zip -d $(dirname {DATASET_DIR})")
    runp(f"rm /tmp/dataset.zip")
else:
    print("Dataset already downloaded!")
# Out:
# rm -rf /code/object-detection/assets/duckietown_object_detection_dataset/*
# mkdir -p /code/object-detection/assets/duckietown_object_detection_dataset/images
# mkdir -p /code/object-detection/assets/duckietown_object_detection_dataset/labels
# mkdir -p /code/object-detection/assets/duckietown_object_detection_dataset/train/images
# mkdir -p /code/object-detection/assets/duckietown_object_detection_dataset/train/labels
# mkdir -p /code/object-detection/assets/duckietown_object_detection_dataset/val/images
# mkdir -p /code/object-detection/assets/duckietown_object_detection_dataset/val/labels
# --2023-08-14 18:45:15--  https://duckietown-public-storage.s3.amazonaws.com/assets/mooc/2022/duckietown_object_detection_dataset.zip
# Resolving duckietown-public-storage.s3.amazonaws.com (duckietown-public-storage.s3.amazonaws.com)... 52.217.227.225, 52.217.10.68, 54.231.202.185, ...
# Connecting to duckietown-public-storage.s3.amazonaws.com (duckietown-public-storage.s3.amazonaws.com)|52.217.227.225|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 703630821 (671M) [binary/octet-stream]
# Saving to: ‘/tmp/dataset.zip’
#
# /tmp/dataset.zip    100%[===================>] 671.03M  1020KB/s    in 23m 42s
#
# 2023-08-14 19:08:59 (483 KB/s) - ‘/tmp/dataset.zip’ saved [703630821/703630821]
#
# unzip -q /tmp/dataset.zip -d $(dirname /code/object-detection/assets/duckietown_object_detection_dataset)
# rm /tmp/dataset.zip

# %% [markdown]
# These real-world images are not the right size. Run the cell bellow to resize them (and resize the associated bounding boxes accordingly).

# %%
import json
import os
import cv2
import numpy as np
from tqdm import tqdm
from utils.misc import xminyminxmaxymax2xywfnormalized, train_test_split, makedirs, runp

with open(f"{DATASET_DIR}/annotation/final_anns.json") as anns:
    annotations = json.load(anns)

# %%
npz_index = 0

all_image_names = []
    
def save_img(img, boxes, classes):
    global npz_index
    cv2.imwrite(f"{DATASET_DIR}/images/real_{npz_index}.jpg", img)
    with open(f"{DATASET_DIR}/labels/real_{npz_index}.txt", "w") as f:
        for i in range(len(boxes)):
            f.write(f"{classes[i]} "+" ".join(map(str,boxes[i]))+"\n")
    npz_index += 1
    all_image_names.append(f"real_{npz_index}")

filenames = tqdm(os.listdir(f"{DATASET_DIR}/frames"))
for filename in filenames:
    img = cv2.imread(f"{DATASET_DIR}/frames/{filename}")

    orig_y, orig_x = img.shape[0], img.shape[1]
    scale_y, scale_x = IMAGE_SIZE/orig_y, IMAGE_SIZE/orig_x

    img = cv2.resize(img, (IMAGE_SIZE,IMAGE_SIZE))

    boxes = []
    classes = []

    if filename not in annotations:
        continue

    for detection in annotations[filename]:
        box = detection["bbox"]
        label = detection["cat_name"]

        if label not in ["duckie", "cone"]:
            continue

        orig_x_min, orig_y_min, orig_w, orig_h = box

        x_min = int(np.round(orig_x_min * scale_x))
        y_min = int(np.round(orig_y_min * scale_y))
        x_max = x_min + int(np.round(orig_w * scale_x))
        y_max = y_min + int(np.round(orig_h * scale_y))

        boxes.append([x_min, y_min, x_max, y_max])
        classes.append(1 if label == "duckie" else 2)

    if len(boxes) == 0:
        continue


    boxes = np.array([xminyminxmaxymax2xywfnormalized(box, IMAGE_SIZE) for box in boxes])
    classes = np.array(classes)-1
    
    save_img(img, boxes, classes)



train_test_split(all_image_names, REAL_TRAIN_TEST_SPLIT_PERCENTAGE, DATASET_DIR)
# Out:
# 100%|██████████| 1963/1963 [00:30<00:00, 65.17it/s]
# ALL IMAGE NAMES TO MOVE DURING THIS SPLIT: ['real_1', 'real_2', 'real_3', 'real_4', 'real_5', 'real_6', 'real_7', 'real_8', 'real_9', 'real_10', 'real_11', 'real_12', 'real_13', 'real_14', 'real_15', 'real_16', 'real_17', 'real_18', 'real_19', 'real_20', 'real_21', 'real_22', 'real_23', 'real_24', 'real_25', 'real_26', 'real_27', 'real_28', 'real_29', 'real_30', 'real_31', 'real_32', 'real_33', 'real_34', 'real_35', 'real_36', 'real_37', 'real_38', 'real_39', 'real_40', 'real_41', 'real_42', 'real_43', 'real_44', 'real_45', 'real_46', 'real_47', 'real_48', 'real_49', 'real_50', 'real_51', 'real_52', 'real_53', 'real_54', 'real_55', 'real_56', 'real_57', 'real_58', 'real_59', 'real_60', 'real_61', 'real_62', 'real_63', 'real_64', 'real_65', 'real_66', 'real_67', 'real_68', 'real_69', 'real_70', 'real_71', 'real_72', 'real_73', 'real_74', 'real_75', 'real_76', 'real_77', 'real_78', 'real_79', 'real_80', 'real_81', 'real_82', 'real_83', 'real_84', 'real_85', 'real_86', 'real_87', 'real_88', 'real_89', 'real_90', 'real_91', 'real_92', 'real_93', 'real_94', 'real_95', 'real_96', 'real_97', 'real_98', 'real_99', 'real_100', 'real_101', 'real_102', 'real_103', 'real_104', 'real_105', 'real_106', 'real_107', 'real_108', 'real_109', 'real_110', 'real_111', 'real_112', 'real_113', 'real_114', 'real_115', 'real_116', 'real_117', 'real_118', 'real_119', 'real_120', 'real_121', 'real_122', 'real_123', 'real_124', 'real_125', 'real_126', 'real_127', 'real_128', 'real_129', 'real_130', 'real_131', 'real_132', 'real_133', 'real_134', 'real_135', 'real_136', 'real_137', 'real_138', 'real_139', 'real_140', 'real_141', 'real_142', 'real_143', 'real_144', 'real_145', 'real_146', 'real_147', 'real_148', 'real_149', 'real_150', 'real_151', 'real_152', 'real_153', 'real_154', 'real_155', 'real_156', 'real_157', 'real_158', 'real_159', 'real_160', 'real_161', 'real_162', 'real_163', 'real_164', 'real_165', 'real_166', 'real_167', 'real_168', 'real_169', 'real_170', 'real_171', 'real_172', 'real_173', 'real_174', 'real_175', 'real_176', 'real_177', 'real_178', 'real_179', 'real_180', 'real_181', 'real_182', 'real_183', 'real_184', 'real_185', 'real_186', 'real_187', 'real_188', 'real_189', 'real_190', 'real_191', 'real_192', 'real_193', 'real_194', 'real_195', 'real_196', 'real_197', 'real_198', 'real_199', 'real_200', 'real_201', 'real_202', 'real_203', 'real_204', 'real_205', 'real_206', 'real_207', 'real_208', 'real_209', 'real_210', 'real_211', 'real_212', 'real_213', 'real_214', 'real_215', 'real_216', 'real_217', 'real_218', 'real_219', 'real_220', 'real_221', 'real_222', 'real_223', 'real_224', 'real_225', 'real_226', 'real_227', 'real_228', 'real_229', 'real_230', 'real_231', 'real_232', 'real_233', 'real_234', 'real_235', 'real_236', 'real_237', 'real_238', 'real_239', 'real_240', 'real_241', 'real_242', 'real_243', 'real_244', 'real_245', 'real_246', 'real_247', 'real_248', 'real_249', 'real_250', 'real_251', 'real_252', 'real_253', 'real_254', 'real_255', 'real_256', 'real_257', 'real_258', 'real_259', 'real_260', 'real_261', 'real_262', 'real_263', 'real_264', 'real_265', 'real_266', 'real_267', 'real_268', 'real_269', 'real_270', 'real_271', 'real_272', 'real_273', 'real_274', 'real_275', 'real_276', 'real_277', 'real_278', 'real_279', 'real_280', 'real_281', 'real_282', 'real_283', 'real_284', 'real_285', 'real_286', 'real_287', 'real_288', 'real_289', 'real_290', 'real_291', 'real_292', 'real_293', 'real_294', 'real_295', 'real_296', 'real_297', 'real_298', 'real_299', 'real_300', 'real_301', 'real_302', 'real_303', 'real_304', 'real_305', 'real_306', 'real_307', 'real_308', 'real_309', 'real_310', 'real_311', 'real_312', 'real_313', 'real_314', 'real_315', 'real_316', 'real_317', 'real_318', 'real_319', 'real_320', 'real_321', 'real_322', 'real_323', 'real_324', 'real_325', 'real_326', 'real_327', 'real_328', 'real_329', 'real_330', 'real_331', 'real_332', 'real_333', 'real_334', 'real_335', 'real_336', 'real_337', 'real_338', 'real_33 ...
# DATASET DIRECTORY /code/object-detection/assets/duckietown_object_detection_dataset
# MOVING IMG NAMED real_535
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_535.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_535.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_535.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_535.txt
# MOVING IMG NAMED real_598
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_598.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_598.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_598.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_598.txt
# MOVING IMG NAMED real_906
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_906.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_906.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_906.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_906.txt
# MOVING IMG NAMED real_492
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_492.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_492.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_492.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_492.txt
# MOVING IMG NAMED real_999
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_999.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_999.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_999.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_999.txt
# MOVING IMG NAMED real_613
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_613.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_613.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_613.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_613.txt
# MOVING IMG NAMED real_862
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_862.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_862.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_862.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_862.txt
# MOVING IMG NAMED real_750
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_750.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_750.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_750.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_750.txt
# MOVING IMG NAMED real_178
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_178.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_178.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_178.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_178.txt
# MOVING IMG NAMED real_637
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_637.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_637.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_637.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_637.txt
# MOVING IMG NAMED real_230
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_230.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_230.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_230.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_230.txt
# MOVING IMG NAMED real_927
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_927.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_927.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_927.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_927.txt
# MOVING IMG NAMED real_654
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_654.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_654.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_654.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_654.txt
# MOVING IMG NAMED real_809
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_809.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_809.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_809.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_809.txt
# MOVING IMG NAMED real_528
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_528.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_528.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_528.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_528.txt
# MOVING IMG NAMED real_330
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_330.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_330.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_330.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_330.txt
# MOVING IMG NAMED real_818
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_818.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_818.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_818.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_818.txt
# MOVING IMG NAMED real_891
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_891.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_891.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_891.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_891.txt
# MOVING IMG NAMED real_64
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_64.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_64.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_64.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_64.txt
# MOVING IMG NAMED real_476
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_476.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_476.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_476.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_476.txt
# MOVING IMG NAMED real_94
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_94.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_94.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_94.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_94.txt
# MOVING IMG NAMED real_1003
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_1003.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_1003.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_1003.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_1003.txt
# MOVING IMG NAMED real_625
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_625.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_625.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_625.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_625.txt
# MOVING IMG NAMED real_864
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_864.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_864.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_864.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_864.txt
# MOVING IMG NAMED real_451
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_451.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_451.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_451.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_451.txt
# MOVING IMG NAMED real_438
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_438.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_438.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_438.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_438.txt
# MOVING IMG NAMED real_470
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_470.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_470.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_470.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_470.txt
# MOVING IMG NAMED real_487
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_487.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_487.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_487.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_487.txt
# MOVING IMG NAMED real_758
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_758.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_758.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_758.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_758.txt
# MOVING IMG NAMED real_38
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_38.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_38.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_38.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_38.txt
# MOVING IMG NAMED real_570
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_570.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_570.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_570.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_570.txt
# MOVING IMG NAMED real_824
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_824.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_824.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_824.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_824.txt
# MOVING IMG NAMED real_150
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_150.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_150.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_150.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_150.txt
# MOVING IMG NAMED real_342
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_342.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_342.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_342.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_342.txt
# MOVING IMG NAMED real_289
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_289.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_289.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_289.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_289.txt
# MOVING IMG NAMED real_955
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_955.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_955.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_955.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_955.txt
# MOVING IMG NAMED real_138
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_138.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_138.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_138.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_138.txt
# MOVING IMG NAMED real_754
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_754.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_754.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_754.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_754.txt
# MOVING IMG NAMED real_881
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_881.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_881.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_881.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_881.txt
# MOVING IMG NAMED real_657
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_657.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_657.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_657.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_657.txt
# MOVING IMG NAMED real_412
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_412.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_412.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_412.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_412.txt
# MOVING IMG NAMED real_806
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_806.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_806.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_806.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_806.txt
# MOVING IMG NAMED real_688
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_688.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_688.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_688.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_688.txt
# MOVING IMG NAMED real_454
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_454.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_454.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_454.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_454.txt
# MOVING IMG NAMED real_674
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_674.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_674.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_674.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_674.txt
# MOVING IMG NAMED real_120
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_120.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_120.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_120.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_120.txt
# MOVING IMG NAMED real_650
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_650.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_650.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_650.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_650.txt
# MOVING IMG NAMED real_693
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_693.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_693.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_693.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_693.txt
# MOVING IMG NAMED real_129
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_129.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_129.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_129.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_129.txt
# MOVING IMG NAMED real_40
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_40.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_40.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_40.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_40.txt
# MOVING IMG NAMED real_987
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_987.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_987.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_987.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_987.txt
# MOVING IMG NAMED real_63
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_63.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_63.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_63.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_63.txt
# MOVING IMG NAMED real_548
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_548.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_548.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_548.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_548.txt
# MOVING IMG NAMED real_897
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_897.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_897.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_897.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_897.txt
# MOVING IMG NAMED real_763
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_763.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_763.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_763.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_763.txt
# MOVING IMG NAMED real_477
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_477.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_477.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_477.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_477.txt
# MOVING IMG NAMED real_444
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_444.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_444.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_444.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_444.txt
# MOVING IMG NAMED real_968
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_968.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_968.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_968.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_968.txt
# MOVING IMG NAMED real_539
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_539.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_539.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_539.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_539.txt
# MOVING IMG NAMED real_1005
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_1005.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_1005.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_1005.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_1005.txt
# MOVING IMG NAMED real_706
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_706.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_706.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_706.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_706.txt
# MOVING IMG NAMED real_902
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_902.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_902.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_902.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_902.txt
# MOVING IMG NAMED real_892
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_892.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_892.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_892.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_892.txt
# MOVING IMG NAMED real_291
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_291.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_291.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_291.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_291.txt
# MOVING IMG NAMED real_465
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_465.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_465.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_465.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_465.txt
# MOVING IMG NAMED real_624
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_624.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_624.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_624.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_624.txt
# MOVING IMG NAMED real_79
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_79.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_79.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_79.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_79.txt
# MOVING IMG NAMED real_527
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_527.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_527.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_527.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_527.txt
# MOVING IMG NAMED real_709
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_709.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_709.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_709.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_709.txt
# MOVING IMG NAMED real_954
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_954.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_954.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_954.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_954.txt
# MOVING IMG NAMED real_739
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_739.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_739.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_739.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_739.txt
# MOVING IMG NAMED real_250
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_250.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_250.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_250.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_250.txt
# MOVING IMG NAMED real_876
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_876.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_876.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_876.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_876.txt
# MOVING IMG NAMED real_577
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_577.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_577.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_577.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_577.txt
# MOVING IMG NAMED real_555
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_555.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_555.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_555.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_555.txt
# MOVING IMG NAMED real_701
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_701.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_701.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_701.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_701.txt
# MOVING IMG NAMED real_791
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_791.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_791.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_791.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_791.txt
# MOVING IMG NAMED real_392
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_392.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_392.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_392.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_392.txt
# MOVING IMG NAMED real_938
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_938.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_938.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_938.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_938.txt
# MOVING IMG NAMED real_667
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_667.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_667.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_667.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_667.txt
# MOVING IMG NAMED real_871
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_871.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_871.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_871.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_871.txt
# MOVING IMG NAMED real_521
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_521.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_521.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_521.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_521.txt
# MOVING IMG NAMED real_164
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_164.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_164.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_164.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_164.txt
# MOVING IMG NAMED real_594
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_594.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_594.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_594.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_594.txt
# MOVING IMG NAMED real_215
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_215.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_215.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_215.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_215.txt
# MOVING IMG NAMED real_161
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_161.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_161.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_161.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_161.txt
# MOVING IMG NAMED real_847
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_847.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_847.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_847.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_847.txt
# MOVING IMG NAMED real_830
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_830.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_830.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_830.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_830.txt
# MOVING IMG NAMED real_651
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_651.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_651.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_651.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_651.txt
# MOVING IMG NAMED real_39
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_39.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_39.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_39.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_39.txt
# MOVING IMG NAMED real_376
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_376.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_376.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_376.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_376.txt
# MOVING IMG NAMED real_721
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_721.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_721.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_721.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_721.txt
# MOVING IMG NAMED real_623
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_623.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_623.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_623.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_623.txt
# MOVING IMG NAMED real_241
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_241.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_241.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_241.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_241.txt
# MOVING IMG NAMED real_853
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_853.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_853.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_853.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_853.txt
# MOVING IMG NAMED real_141
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_141.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_141.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_141.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_141.txt
# MOVING IMG NAMED real_937
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_937.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_937.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_937.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_937.txt
# MOVING IMG NAMED real_922
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_922.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_922.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_922.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_922.txt
# MOVING IMG NAMED real_149
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_149.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_149.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_149.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_149.txt
# MOVING IMG NAMED real_717
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_717.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_717.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_717.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_717.txt
# MOVING IMG NAMED real_72
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_72.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_72.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_72.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_72.txt
# MOVING IMG NAMED real_832
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_832.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_832.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_832.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_832.txt
# MOVING IMG NAMED real_811
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_811.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_811.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_811.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_811.txt
# MOVING IMG NAMED real_498
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_498.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_498.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_498.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_498.txt
# MOVING IMG NAMED real_219
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_219.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_219.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_219.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_219.txt
# MOVING IMG NAMED real_893
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_893.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_893.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_893.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_893.txt
# MOVING IMG NAMED real_502
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_502.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_502.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_502.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_502.txt
# MOVING IMG NAMED real_644
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_644.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_644.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_644.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_644.txt
# MOVING IMG NAMED real_554
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_554.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_554.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_554.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_554.txt
# MOVING IMG NAMED real_384
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_384.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_384.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_384.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_384.txt
# MOVING IMG NAMED real_1007
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_1007.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_1007.jpg
# mv: cannot stat '/code/object-detection/assets/duckietown_object_detection_dataset/images/real_1007.jpg': No such file or directory
#
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_1007.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_1007.txt
# mv: cannot stat '/code/object-detection/assets/duckietown_object_detection_dataset/labels/real_1007.txt': No such file or directory
#
# MOVING IMG NAMED real_252
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_252.jpg /code/object-detection/assets/duckietown_object_detection_dataset/train/images/real_252.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_252.txt /code/object-detection/assets/duckietown_object_detection_dataset/train/labels/real_252.txt
# MOVING IMG NAMED real_699
# ...
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_720.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_720.txt
# MOVING IMG NAMED real_35
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_35.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_35.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_35.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_35.txt
# MOVING IMG NAMED real_317
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_317.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_317.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_317.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_317.txt
# MOVING IMG NAMED real_308
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_308.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_308.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_308.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_308.txt
# MOVING IMG NAMED real_65
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_65.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_65.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_65.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_65.txt
# MOVING IMG NAMED real_675
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_675.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_675.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_675.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_675.txt
# MOVING IMG NAMED real_299
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_299.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_299.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_299.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_299.txt
# MOVING IMG NAMED real_495
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_495.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_495.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_495.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_495.txt
# MOVING IMG NAMED real_550
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_550.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_550.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_550.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_550.txt
# MOVING IMG NAMED real_273
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_273.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_273.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_273.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_273.txt
# MOVING IMG NAMED real_8
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_8.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_8.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_8.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_8.txt
# MOVING IMG NAMED real_647
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_647.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_647.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_647.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_647.txt
# MOVING IMG NAMED real_50
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_50.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_50.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_50.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_50.txt
# MOVING IMG NAMED real_978
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_978.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_978.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_978.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_978.txt
# MOVING IMG NAMED real_154
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_154.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_154.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_154.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_154.txt
# MOVING IMG NAMED real_812
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_812.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_812.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_812.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_812.txt
# MOVING IMG NAMED real_346
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_346.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_346.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_346.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_346.txt
# MOVING IMG NAMED real_207
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_207.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_207.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_207.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_207.txt
# MOVING IMG NAMED real_951
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_951.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_951.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_951.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_951.txt
# MOVING IMG NAMED real_277
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_277.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_277.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_277.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_277.txt
# MOVING IMG NAMED real_379
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_379.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_379.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_379.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_379.txt
# MOVING IMG NAMED real_281
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_281.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_281.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_281.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_281.txt
# MOVING IMG NAMED real_284
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_284.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_284.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_284.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_284.txt
# MOVING IMG NAMED real_884
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_884.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_884.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_884.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_884.txt
# MOVING IMG NAMED real_740
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_740.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_740.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_740.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_740.txt
# MOVING IMG NAMED real_21
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_21.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_21.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_21.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_21.txt
# MOVING IMG NAMED real_208
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_208.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_208.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_208.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_208.txt
# MOVING IMG NAMED real_928
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_928.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_928.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_928.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_928.txt
# MOVING IMG NAMED real_202
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_202.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_202.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_202.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_202.txt
# MOVING IMG NAMED real_232
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_232.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_232.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_232.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_232.txt
# MOVING IMG NAMED real_890
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_890.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_890.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_890.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_890.txt
# MOVING IMG NAMED real_93
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_93.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_93.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_93.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_93.txt
# MOVING IMG NAMED real_147
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_147.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_147.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_147.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_147.txt
# MOVING IMG NAMED real_316
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_316.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_316.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_316.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_316.txt
# MOVING IMG NAMED real_1000
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_1000.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_1000.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_1000.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_1000.txt
# MOVING IMG NAMED real_531
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_531.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_531.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_531.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_531.txt
# MOVING IMG NAMED real_724
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_724.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_724.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_724.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_724.txt
# MOVING IMG NAMED real_405
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_405.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_405.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_405.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_405.txt
# MOVING IMG NAMED real_407
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_407.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_407.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_407.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_407.txt
# MOVING IMG NAMED real_78
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_78.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_78.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_78.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_78.txt
# MOVING IMG NAMED real_708
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_708.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_708.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_708.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_708.txt
# MOVING IMG NAMED real_353
# mv /code/object-detection/assets/duckietown_object_detection_dataset/images/real_353.jpg /code/object-detection/assets/duckietown_object_detection_dataset/val/images/real_353.jpg
# mv /code/object-detection/assets/duckietown_object_detection_dataset/labels/real_353.txt /code/object-detection/assets/duckietown_object_detection_dataset/val/labels/real_353.txt

# %% [markdown]
# Once that's done, you're all set! We'll explain how the code above worked as you continue through this notebook.
#
# ## 2. Investigation
#
# What does an object detection dataset look like? Clearly, the specifics will depend on the convention used by specific models, but the general idea is intuitive:
#
# - We need an image
# - This image might have many bounding boxes in it, so we need some sort of list of coordinates
# - These bounding boxes must be associated with a class
#
# How are the bounding boxes defined?
#
# ![image of a bounding box](../../assets/images/bbox.png)
#
# Some conventions use `x_min y_min width height`, whereas others use `x_min y_min x_max y_max`, and others use `x_center y_center width height`. In this exercise, the model we recommend ([YoloV5](https://github.com/Velythyl/yolov5)) uses `x_center y_center width height`.
#
# And how do we actually obtain these bounding boxes? In real-life applications, you would need to label a dataset of images by hand. But if you have access to a simulator that is able to segment images, you could obtain the bounding boxes directly from the segmented images.
#
# If you take a look at Pytorch's object detection [tutorial](https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html), that is similar to what they do. While their images were segmented by hand, the tutorial uses the same technique that we will use here to obtain the bounding boxes. Their images look like this:
#
# ![image with bounding boxes](../../assets/images/FudanPed.png)
#
# And they simply calculate the min and max x and y coordinates of the segmented objects to obtain the bounding box.
#
# We will use the segmented mode in the Duckietown simulator to compute the bounding boxes of non-segmented images.
#
# #### What we want to detect
#
# The goal of this exercise is to make Duckietown safer: we want to be able to detect duckie pedestrians on the road and avoid squishing them. We also want to detect trucks, buses, and cones. Here is the complete list, along with their corresponding IDs:
#
# | Object    | ID    |
# | ---       | ---   |
# | Duckie    | 0     |
# | Cone      | 1     |
# | Truck     | 2     |
# | Bus       | 3     |

# %% [markdown]
# ## 3. Data collection
#
#
# ### Tool and Format
#
# We are going to supplement the data from the real dataset that we already downloaded with data automatically *generated from the simulator*.  The script we will use for this is the [data_collection.py](../../packages/utils/data_collection.py) file. You can edit the file in order to change the some parameters on what to generate, e.g. the number of images generated, which maps to be used by the simulator. More parameters (with description) can be found in the file, under the comment line:
#
# ![img](../../assets/images/setup_instr_data_col_0.png)
#
#
# The purpose of the [data_collection.py](../../packages/utils/data_collection.py) script is to automatically generate data for you from the simulator.
# In the rest of this activity we will walk step by step through the process.
#
# Of course, your dataset's format depends heavily on your model. If you want to use the [YoloV5](https://github.com/duckietown/yolov5) model that we suggest, you should closely follow their [guide on how to train using custom data](https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data). Your data should follow the following directory structure:
#
# ![image of dataset save format](../../assets/images/dataset_format.png)
#
# The dataset is called `duckietown_object_detection_dataset` and is stored inside the `assets/` directory of this learning experience.
# We have created two subdirectories in that folder: `train` and `val`. Both these directories should contain two subdirectories, `images` and `labels`. Inside `images`, you must place your images, and inside `labels`, you must place the images' bounding boxes data. Notice that the label files use the same name as their corresponding image files but with a different extension. In other words, the data for `0.jpg` can be found in `0.txt`.
#
# The format for the label files is fairly simple. For each bounding box in the corresponding image, write a row of the form `class x_center y_center width height`. Keep in mind that the pixel data must be 0-to-1 normalized (i.e., you can calculate the usual `x_center y_center width height` in pixel space and divide by the image's size). For example,
#
#     0 0.5 0.5 0.2 0.2
#     1 0.60 0.70 0.4 0.2
#
# this says "there is a duckie (class 0) centered in the image, whose width and height are 20% of the image's. There is also a cone (class 1) whose center is at 60% of the image's maximal x value and 70% of the image's maximal y value, and its width is 40% of the image's own while its height is 20%."
#
# Again, it is recommended that you read the guide posted on YoloV5's GitHub: [guide on how to train using custom data](https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data).

# %% [markdown]
# ### Running data collection
#
# After you're done editing the [data_collection.py](../../packages/utils/data_collection.py) file, we will need to run it against the simulator.
# We will do that through this activity's virtual desktop environment. (Run the following 2 commands from the root directory of this activity)
#
# * First, let's prepare the environment for this activity to run in.
#
#     ```shell
#     dts code build
#     ```
#
# * Then, access this activity's virtual desktop (also known and referred to as `VNC`) by ,
#
#     ```shell
#     dts code workbench --simulation --launcher data-collection
#     ```
#
# * Open the VNC with the URL that you see on screen, among the terminal logs
#     * Cmd/Ctrl + Click on the link, or
#     * Copy-paste the link to your browser address bar
#     * The link looks like this:
#     ![](../../assets/images/setup_instr_vnc.png)
#
#
#
# Then, click the "Data Collection" icon on the desktop.
# This will run your [data_collection.py](../../packages/utils/data_collection.py) script file.
#
# You will see a simulator view and the agent moving while collecting images. The process will load different maps and randomize time of day, starting location and heading and other aspects of the environment. Wait until the simulator view window and the terminal terminate and close automatically.
#
# * This is what you should expect to see. The collection progress is shown in the terminal. The image view shows the segmented scene, while we save the original image for training (see next section).
#     ![](../../assets/images/setup_instr_data_col_1.png)
#
# Later, if you edit the script again in this editor, you need to close the "Data Collection" application and click on the icon again for the changes to have an effect. Also, remove the images in `assets/duckietown_object_detection_dataset/[train|val]/images` folders, which do NOT start with `real_`.
#
# Once satisfied, you can close the VNC browser tab and terminate the `dts code workbench` command above by pressing Ctrl-C in your terminal.

# %% [markdown]
# ### Data generation/collection procedure explained
#
# In this section, we take some sample images and illustrate how the data collection script generates labels for the data from our simulator.
#
# #### 1. Take the segmented image (this is provided to you by the simulator's rendering engine)

# %%
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt
mapping = {
    "house": "3deb34",
    "bus": "ebd334",
    "truck": "961fad",
    "duckie": "cfa923",
    "cone": "ffa600",
    "floor": "000000",
    "grass": "af0000",
    "barrier": "000099",
    "duckiebot": "ad0000"
}
mapping = {
    key:
        [int(h[i:i+2], 16) for i in (0,2,4)]
    for key, h in mapping.items()
}

# %%
# Feel free to experiment with a few other files in the images folder. All of the original/segmented pairs are labeled as *_not_seg and *_seg
obs = np.asarray(Image.open('../../assets/images/208.jpg'))
obs_seg = np.asarray(Image.open('../../assets/images/208.png'))

# obs = np.asarray(Image.open('../../assets/images/duckie_not_seg.png'))
# obs_seg = np.asarray(Image.open('../../assets/images/duckie_seg.png'))

# obs = np.flip(obs, axis=1)
# obs_seg = np.flip(obs_seg, axis =1)
# define the mapping from objects to colours

# %%
plt.imshow(obs)

# %%
plt.imshow(obs_seg)

# %% [markdown]
# #### 2. Remove colors we are not interested in
#
# The function below removes all colors that do not match the given class name.
# We use this to isolate the objects of interest by isolating their respective color first.

# %%
from solution.setup_activity import segmented_image_one_class

# %% [markdown]
# Let's test it out by removing everything that is not a duckie in the image above.

# %%
duckie_masked_image = segmented_image_one_class(np.asarray(obs_seg),"duckie")
plt.imshow(duckie_masked_image)

# %% [markdown]
# #### 3. Find bounding boxes around each unique instance within the image
#
# The function below isolates the object by finding the contours of the colored blob in the image above.
#
# This results in the bounding box around the object.

# %%
from solution.setup_activity import find_all_bboxes

# %% [markdown]
# The function below takes the original image and computed bounding boxes and superimposes the bounding boxes to the image.

# %%
def show_image_with_boxes(img, boxes):
    import matplotlib.patches as patches
    fig, ax = plt.subplots()
    ax.imshow(img)
    for box in boxes:
        rect = patches.Rectangle((box[1], box[2]), box[1]-box[0], box[3]-box[2], linewidth=1, edgecolor='w', facecolor='none')
        ax.add_patch(rect)

        # Draw dots at the top-left and bottom-right corners
        top_left_dot = patches.Circle((box[1], box[2]), radius=3, color='red')
        bottom_right_dot = patches.Circle((box[0], box[3]), radius=3, color='blue')

        ax.add_patch(top_left_dot)
        ax.add_patch(bottom_right_dot)
        
    plt.show()

# %% [markdown]
# Let's test these functions out on the image above.

# %%
boxes = find_all_bboxes(duckie_masked_image)
# gray = find_all_bboxes(duckie_masked_image)[1]
# contours = find_all_bboxes(duckie_masked_image)[2]
# hierarchy = find_all_bboxes(duckie_masked_image)[3]
show_image_with_boxes(obs_seg,boxes)
print(boxes)
# plt.imshow(gray)
# plt.show()
# print("contours", contours)
# print("hierarchy", hierarchy)
# Out:
# [[169 143 210 229]]

# %% [markdown]
# #### 4. Let's do that but for all classes

# %%
from solution.setup_activity import find_all_boxes_and_classes

# %%
all_boxes, all_classes = find_all_boxes_and_classes(obs_seg)
show_image_with_boxes(obs, all_boxes)

# %%
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_9733/2101128340.py in <cell line: 28>()
#      56
#      57     # Write the largest bounding box and other bounding boxes to a new text file
# ---> 58     with open(f"{DATASET_DIR}/labels/{filename}", 'w') as new_file:
#      59         # Write the other bounding boxes
#      60         new_file.writelines(other_bboxes)
#
# PermissionError: [Errno 13] Permission denied: '/code/object-detection/assets/duckietown_object_detection_dataset/labels/955.txt'

# %% [markdown]
# Finally we save the ***non-segmented*** version of the image, and write its bounding boxes + their classes to a corresponding txt file. The above steps demonstrate what is implemented in the [data_collection.py](../../packages/utils/data_collection.py) file.

# %% [markdown]
# ### Combining with the real dataset & training/test set splits
#
# When training supervised learning models, one must worry about overfitting to the training set. If you can keep *some* of your dataset *out* of your training data, you can use it to verify that your model does not overfit to your dataset by *testing* it on the data you left out. We call this chunk of data the *validation set*.
#
# You can experiment with the `REAL_TRAIN_TEST_SPLIT_PERCENTAGE` variable defined at the top of this notebook. Tune its value to adjust the percentage of the **real** data that is used for training as opposed to testing. There is a similar variable defined in [data_collection.py](../../packages/utils/data_collection.py), called `SIMULATED_TRAIN_SPLIT_PERCENTAGE` which controls the percentage of the **simulated** data that will be used for training.

# %% [markdown]
# # Next step
#
# You can continue with the [Training notebook](../03-Training/training.ipynb)
